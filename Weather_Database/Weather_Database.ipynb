# %%
#import required libraries for the code
import numpy as np
import pandas as pd
from citipy import citipy
import requests 
import os
import sys
sys.path.append(os.path.abspath('../'))
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]['description']

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | alice springs
# Processing Record 2 of Set 1 | kodiak
# Processing Record 3 of Set 1 | grande prairie
# Processing Record 4 of Set 1 | warmbad
# Processing Record 5 of Set 1 | pozo colorado
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | mercedes
# Processing Record 8 of Set 1 | alofi
# Processing Record 9 of Set 1 | kununurra
# Processing Record 10 of Set 1 | hukuntsi
# Processing Record 11 of Set 1 | provideniya
# Processing Record 12 of Set 1 | ribeira grande
# Processing Record 13 of Set 1 | okhotsk
# Processing Record 14 of Set 1 | constitucion
# Processing Record 15 of Set 1 | maniitsoq
# Processing Record 16 of Set 1 | tuktoyaktuk
# Processing Record 17 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 18 of Set 1 | buzmeyin
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | pevek
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | san luis
# Processing Record 23 of Set 1 | biak
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | namibe
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | sabang
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | sao joao da barra
# Processing Record 31 of Set 1 | talcahuano
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | thompson
# Processing Record 34 of Set 1 | chicama
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | luderitz
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | ucluelet
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | nelson bay
# Processing Record 41 of Set 1 | airai
# Processing Record 42 of Set 1 | carutapera
# Processing Record 43 of Set 1 | havelock
# Processing Record 44 of Set 1 | natal
# Processing Record 45 of Set 1 | little chute
# Processing Record 46 of Set 1 | burica
# City not found. Skipping...
# Processing Record 47 of Set 1 | hobart
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | buala
# Processing Record 50 of Set 1 | santiago del estero
# Processing Record 1 of Set 2 | leningradskiy
# Processing Record 2 of Set 2 | orcopampa
# Processing Record 3 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 2 | mar del plata
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | grand gaube
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | kavieng
# Processing Record 9 of Set 2 | norman wells
# Processing Record 10 of Set 2 | monywa
# Processing Record 11 of Set 2 | moron
# Processing Record 12 of Set 2 | trincomalee
# Processing Record 13 of Set 2 | pitimbu
# Processing Record 14 of Set 2 | kungurtug
# Processing Record 15 of Set 2 | mareeba
# Processing Record 16 of Set 2 | buchanan
# Processing Record 17 of Set 2 | sangar
# Processing Record 18 of Set 2 | saldanha
# Processing Record 19 of Set 2 | moche
# Processing Record 20 of Set 2 | pacific grove
# Processing Record 21 of Set 2 | longyearbyen
# Processing Record 22 of Set 2 | neuquen
# Processing Record 23 of Set 2 | upernavik
# Processing Record 24 of Set 2 | chitral
# Processing Record 25 of Set 2 | new norfolk
# Processing Record 26 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | mataura
# Processing Record 29 of Set 2 | cuaspud
# Processing Record 30 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 2 | el faiyum
# City not found. Skipping...
# Processing Record 32 of Set 2 | fort nelson
# Processing Record 33 of Set 2 | dabola
# Processing Record 34 of Set 2 | puerto ayora
# Processing Record 35 of Set 2 | rikitea
# Processing Record 36 of Set 2 | tasiilaq
# Processing Record 37 of Set 2 | cabo san lucas
# Processing Record 38 of Set 2 | nizhniy kuranakh
# Processing Record 39 of Set 2 | ankpa
# Processing Record 40 of Set 2 | uni
# Processing Record 41 of Set 2 | east london
# Processing Record 42 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 2 | hilo
# Processing Record 44 of Set 2 | butaritari
# Processing Record 45 of Set 2 | barrow
# Processing Record 46 of Set 2 | coahuayana
# Processing Record 47 of Set 2 | lagoa
# Processing Record 48 of Set 2 | port alfred
# Processing Record 49 of Set 2 | mahebourg
# Processing Record 50 of Set 2 | mildura
# Processing Record 1 of Set 3 | souillac
# Processing Record 2 of Set 3 | dikson
# Processing Record 3 of Set 3 | vila velha
# Processing Record 4 of Set 3 | severo-kurilsk
# Processing Record 5 of Set 3 | mnogovershinnyy
# Processing Record 6 of Set 3 | chuy
# Processing Record 7 of Set 3 | timra
# Processing Record 8 of Set 3 | cedar city
# Processing Record 9 of Set 3 | uthal
# Processing Record 10 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 3 | tutoia
# Processing Record 12 of Set 3 | saskylakh
# Processing Record 13 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 3 | flinders
# Processing Record 15 of Set 3 | cape town
# Processing Record 16 of Set 3 | cherskiy
# Processing Record 17 of Set 3 | avarua
# Processing Record 18 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 3 | dirba
# Processing Record 20 of Set 3 | meulaboh
# Processing Record 21 of Set 3 | menongue
# Processing Record 22 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 3 | vera cruz
# Processing Record 24 of Set 3 | hailey
# Processing Record 25 of Set 3 | lompoc
# Processing Record 26 of Set 3 | georgetown
# Processing Record 27 of Set 3 | vagur
# Processing Record 28 of Set 3 | maragogi
# Processing Record 29 of Set 3 | chukhloma
# Processing Record 30 of Set 3 | vao
# Processing Record 31 of Set 3 | aranos
# Processing Record 32 of Set 3 | nantucket
# Processing Record 33 of Set 3 | bud
# Processing Record 34 of Set 3 | aripuana
# Processing Record 35 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 3 | tuatapere
# Processing Record 38 of Set 3 | chokurdakh
# Processing Record 39 of Set 3 | meadow lake
# Processing Record 40 of Set 3 | poum
# Processing Record 41 of Set 3 | iralaya
# Processing Record 42 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 3 | anloga
# Processing Record 44 of Set 3 | vaini
# Processing Record 45 of Set 3 | vila franca do campo
# Processing Record 46 of Set 3 | lysva
# Processing Record 47 of Set 3 | tiksi
# Processing Record 48 of Set 3 | karratha
# Processing Record 49 of Set 3 | peniche
# Processing Record 50 of Set 3 | kommunar
# Processing Record 1 of Set 4 | san andres
# Processing Record 2 of Set 4 | faanui
# Processing Record 3 of Set 4 | geraldton
# Processing Record 4 of Set 4 | mackay
# Processing Record 5 of Set 4 | vanimo
# Processing Record 6 of Set 4 | torbay
# Processing Record 7 of Set 4 | walvis bay
# Processing Record 8 of Set 4 | husavik
# Processing Record 9 of Set 4 | teknaf
# Processing Record 10 of Set 4 | verkhnyaya inta
# Processing Record 11 of Set 4 | chara
# Processing Record 12 of Set 4 | hermanus
# Processing Record 13 of Set 4 | te anau
# Processing Record 14 of Set 4 | goderich
# Processing Record 15 of Set 4 | saint george
# Processing Record 16 of Set 4 | nueve de julio
# Processing Record 17 of Set 4 | rathcoole
# Processing Record 18 of Set 4 | kaitangata
# Processing Record 19 of Set 4 | kieta
# Processing Record 20 of Set 4 | iqaluit
# Processing Record 21 of Set 4 | juanjui
# Processing Record 22 of Set 4 | casma
# Processing Record 23 of Set 4 | rajapur
# Processing Record 24 of Set 4 | joigny
# Processing Record 25 of Set 4 | tilichiki
# Processing Record 26 of Set 4 | esperance
# Processing Record 27 of Set 4 | sacama
# Processing Record 28 of Set 4 | banjar
# Processing Record 29 of Set 4 | touros
# Processing Record 30 of Set 4 | rio gallegos
# Processing Record 31 of Set 4 | sur
# Processing Record 32 of Set 4 | oranjemund
# Processing Record 33 of Set 4 | taoudenni
# Processing Record 34 of Set 4 | la guardia
# Processing Record 35 of Set 4 | port lincoln
# Processing Record 36 of Set 4 | hithadhoo
# Processing Record 37 of Set 4 | college
# Processing Record 38 of Set 4 | santa cruz de tenerife
# Processing Record 39 of Set 4 | kokstad
# Processing Record 40 of Set 4 | uricani
# Processing Record 41 of Set 4 | port macquarie
# Processing Record 42 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 4 | vila do maio
# Processing Record 44 of Set 4 | kruisfontein
# Processing Record 45 of Set 4 | lolodorf
# Processing Record 46 of Set 4 | dargaville
# Processing Record 47 of Set 4 | nikolskoye
# Processing Record 48 of Set 4 | ketchikan
# Processing Record 49 of Set 4 | narrabri
# Processing Record 50 of Set 4 | pasighat
# Processing Record 1 of Set 5 | salo
# Processing Record 2 of Set 5 | never
# Processing Record 3 of Set 5 | chapais
# Processing Record 4 of Set 5 | narsaq
# Processing Record 5 of Set 5 | general cepeda
# Processing Record 6 of Set 5 | toledo
# Processing Record 7 of Set 5 | talnakh
# Processing Record 8 of Set 5 | lavrentiya
# Processing Record 9 of Set 5 | saleilua
# City not found. Skipping...
# Processing Record 10 of Set 5 | nenjiang
# Processing Record 11 of Set 5 | guerrero negro
# Processing Record 12 of Set 5 | klaksvik
# Processing Record 13 of Set 5 | port hedland
# Processing Record 14 of Set 5 | edgewater
# Processing Record 15 of Set 5 | amapa
# Processing Record 16 of Set 5 | waingapu
# Processing Record 17 of Set 5 | khuzdar
# Processing Record 18 of Set 5 | tazovskiy
# Processing Record 19 of Set 5 | ous
# Processing Record 20 of Set 5 | tura
# Processing Record 21 of Set 5 | nampula
# Processing Record 22 of Set 5 | castro
# Processing Record 23 of Set 5 | bayamo
# Processing Record 24 of Set 5 | odweyne
# Processing Record 25 of Set 5 | canar
# Processing Record 26 of Set 5 | puksoozero
# Processing Record 27 of Set 5 | lorengau
# Processing Record 28 of Set 5 | arraial do cabo
# Processing Record 29 of Set 5 | cetraro
# Processing Record 30 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 5 | ixtapa
# Processing Record 32 of Set 5 | akranes
# Processing Record 33 of Set 5 | oistins
# Processing Record 34 of Set 5 | lander
# Processing Record 35 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 5 | shimoda
# Processing Record 37 of Set 5 | marabba
# Processing Record 38 of Set 5 | kahului
# Processing Record 39 of Set 5 | port said
# Processing Record 40 of Set 5 | uyuni
# Processing Record 41 of Set 5 | gizo
# Processing Record 42 of Set 5 | san cristobal
# Processing Record 43 of Set 5 | comodoro rivadavia
# Processing Record 44 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 5 | gao
# Processing Record 46 of Set 5 | soe
# Processing Record 47 of Set 5 | carnarvon
# Processing Record 48 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 5 | mehamn
# Processing Record 50 of Set 5 | san patricio
# Processing Record 1 of Set 6 | khatanga
# Processing Record 2 of Set 6 | rioja
# Processing Record 3 of Set 6 | alegrete
# Processing Record 4 of Set 6 | coruripe
# Processing Record 5 of Set 6 | pochutla
# Processing Record 6 of Set 6 | victoria
# Processing Record 7 of Set 6 | ilulissat
# Processing Record 8 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 9 of Set 6 | kalmunai
# Processing Record 10 of Set 6 | eureka
# Processing Record 11 of Set 6 | ponta do sol
# Processing Record 12 of Set 6 | henties bay
# Processing Record 13 of Set 6 | zhob
# Processing Record 14 of Set 6 | prince rupert
# Processing Record 15 of Set 6 | surt
# Processing Record 16 of Set 6 | ahipara
# Processing Record 17 of Set 6 | birin
# Processing Record 18 of Set 6 | belmonte
# Processing Record 19 of Set 6 | shadrinsk
# Processing Record 20 of Set 6 | makakilo city
# Processing Record 21 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 6 | bubaque
# Processing Record 23 of Set 6 | tumen
# Processing Record 24 of Set 6 | itaituba
# Processing Record 25 of Set 6 | viedma
# Processing Record 26 of Set 6 | sao francisco do sul
# Processing Record 27 of Set 6 | dali
# Processing Record 28 of Set 6 | honningsvag
# Processing Record 29 of Set 6 | taksimo
# Processing Record 30 of Set 6 | namatanai
# Processing Record 31 of Set 6 | kasempa
# Processing Record 32 of Set 6 | makat
# Processing Record 33 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 34 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 6 | peno
# Processing Record 36 of Set 6 | gurskoye
# City not found. Skipping...
# Processing Record 37 of Set 6 | portland
# Processing Record 38 of Set 6 | mayumba
# Processing Record 39 of Set 6 | marsa
# Processing Record 40 of Set 6 | codrington
# Processing Record 41 of Set 6 | nagato
# Processing Record 42 of Set 6 | fukue
# Processing Record 43 of Set 6 | oktyabrskiy
# Processing Record 44 of Set 6 | naze
# Processing Record 45 of Set 6 | minas
# Processing Record 46 of Set 6 | salinas
# Processing Record 47 of Set 6 | sorland
# Processing Record 48 of Set 6 | griffith
# Processing Record 49 of Set 6 | saint-philippe
# Processing Record 50 of Set 6 | kutum
# Processing Record 1 of Set 7 | raudeberg
# Processing Record 2 of Set 7 | sao filipe
# Processing Record 3 of Set 7 | shitanjing
# Processing Record 4 of Set 7 | cap malheureux
# Processing Record 5 of Set 7 | dingle
# Processing Record 6 of Set 7 | opuwo
# Processing Record 7 of Set 7 | svetlaya
# Processing Record 8 of Set 7 | ayan
# Processing Record 9 of Set 7 | nynashamn
# Processing Record 10 of Set 7 | lebu
# Processing Record 11 of Set 7 | rocha
# Processing Record 12 of Set 7 | laguna
# Processing Record 13 of Set 7 | police
# Processing Record 14 of Set 7 | richards bay
# Processing Record 15 of Set 7 | kwekwe
# Processing Record 16 of Set 7 | tefe
# Processing Record 17 of Set 7 | tungkang
# City not found. Skipping...
# Processing Record 18 of Set 7 | ushtobe
# Processing Record 19 of Set 7 | araouane
# Processing Record 20 of Set 7 | padang
# Processing Record 21 of Set 7 | qui nhon
# Processing Record 22 of Set 7 | kavaratti
# Processing Record 23 of Set 7 | caravelas
# Processing Record 24 of Set 7 | lata
# Processing Record 25 of Set 7 | dondo
# Processing Record 26 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 7 | texiguat
# Processing Record 28 of Set 7 | kencong
# Processing Record 29 of Set 7 | el balyana
# City not found. Skipping...
# Processing Record 30 of Set 7 | yerbogachen
# Processing Record 31 of Set 7 | hadejia
# Processing Record 32 of Set 7 | quang ngai
# Processing Record 33 of Set 7 | port blair
# Processing Record 34 of Set 7 | savannah bight
# Processing Record 35 of Set 7 | poya
# Processing Record 36 of Set 7 | nouadhibou
# Processing Record 37 of Set 7 | samarai
# Processing Record 38 of Set 7 | jalu
# Processing Record 39 of Set 7 | alugan
# Processing Record 40 of Set 7 | kamenka
# Processing Record 41 of Set 7 | omidiyeh
# Processing Record 42 of Set 7 | turtkul
# City not found. Skipping...
# Processing Record 43 of Set 7 | liuhe
# Processing Record 44 of Set 7 | sitka
# Processing Record 45 of Set 7 | cacoal
# Processing Record 46 of Set 7 | tromso
# Processing Record 47 of Set 7 | krivosheino
# Processing Record 48 of Set 7 | arlit
# Processing Record 49 of Set 7 | monticello
# Processing Record 50 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 1 of Set 8 | bridlington
# Processing Record 2 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 8 | aswan
# Processing Record 4 of Set 8 | amberieu-en-bugey
# Processing Record 5 of Set 8 | simplicio mendes
# Processing Record 6 of Set 8 | garowe
# Processing Record 7 of Set 8 | cassilandia
# Processing Record 8 of Set 8 | hasaki
# Processing Record 9 of Set 8 | alberdi
# Processing Record 10 of Set 8 | yushala
# Processing Record 11 of Set 8 | polis
# Processing Record 12 of Set 8 | emilio carranza
# Processing Record 13 of Set 8 | la rioja
# Processing Record 14 of Set 8 | cayenne
# Processing Record 15 of Set 8 | tekeli
# Processing Record 16 of Set 8 | antalaha
# Processing Record 17 of Set 8 | darhan
# Processing Record 18 of Set 8 | palauig
# Processing Record 19 of Set 8 | mujiayingzi
# Processing Record 20 of Set 8 | lucapa
# Processing Record 21 of Set 8 | dustlik
# Processing Record 22 of Set 8 | vardo
# Processing Record 23 of Set 8 | banda aceh
# Processing Record 24 of Set 8 | maun
# Processing Record 25 of Set 8 | katsuura
# Processing Record 26 of Set 8 | riberalta
# Processing Record 27 of Set 8 | fernley
# Processing Record 28 of Set 8 | lianran
# Processing Record 29 of Set 8 | palmer
# Processing Record 30 of Set 8 | mahanje
# Processing Record 31 of Set 8 | tocopilla
# Processing Record 32 of Set 8 | byron bay
# Processing Record 33 of Set 8 | varciorog
# Processing Record 34 of Set 8 | taltal
# Processing Record 35 of Set 8 | bambous virieux
# Processing Record 36 of Set 8 | atar
# Processing Record 37 of Set 8 | kathmandu
# Processing Record 38 of Set 8 | ouesso
# Processing Record 39 of Set 8 | ponta delgada
# Processing Record 40 of Set 8 | huarmey
# Processing Record 41 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 42 of Set 8 | pokosnoye
# Processing Record 43 of Set 8 | perevolotskiy
# Processing Record 44 of Set 8 | ust-omchug
# Processing Record 45 of Set 8 | biltine
# Processing Record 46 of Set 8 | skjervoy
# Processing Record 47 of Set 8 | bandar penggaram
# City not found. Skipping...
# Processing Record 48 of Set 8 | hay river
# Processing Record 49 of Set 8 | puerto escondido
# Processing Record 50 of Set 8 | vostok
# Processing Record 1 of Set 9 | krapivinskiy
# Processing Record 2 of Set 9 | severo-yeniseyskiy
# Processing Record 3 of Set 9 | woodward
# Processing Record 4 of Set 9 | male
# Processing Record 5 of Set 9 | ust-maya
# Processing Record 6 of Set 9 | san ignacio
# Processing Record 7 of Set 9 | felidhoo
# City not found. Skipping...
# Processing Record 8 of Set 9 | agirish
# Processing Record 9 of Set 9 | guicheng
# City not found. Skipping...
# Processing Record 10 of Set 9 | havoysund
# Processing Record 11 of Set 9 | canora
# Processing Record 12 of Set 9 | mana
# Processing Record 13 of Set 9 | tautira
# Processing Record 14 of Set 9 | dunedin
# Processing Record 15 of Set 9 | matara
# Processing Record 16 of Set 9 | boende
# Processing Record 17 of Set 9 | aliwal north
# Processing Record 18 of Set 9 | trinidad
# Processing Record 19 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 20 of Set 9 | daru
# Processing Record 21 of Set 9 | bac lieu
# Processing Record 22 of Set 9 | santa cruz del sur
# Processing Record 23 of Set 9 | ajtos
# Processing Record 24 of Set 9 | cidreira
# Processing Record 25 of Set 9 | merrill
# Processing Record 26 of Set 9 | thoen
# Processing Record 27 of Set 9 | churapcha
# Processing Record 28 of Set 9 | pangnirtung
# Processing Record 29 of Set 9 | bathsheba
# Processing Record 30 of Set 9 | grootfontein
# Processing Record 31 of Set 9 | formosa do rio preto
# Processing Record 32 of Set 9 | sinnamary
# Processing Record 33 of Set 9 | rabo de peixe
# Processing Record 34 of Set 9 | panzhihua
# Processing Record 35 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 9 | coihaique
# Processing Record 37 of Set 9 | abu samrah
# Processing Record 38 of Set 9 | konongo
# Processing Record 39 of Set 9 | kandrian
# Processing Record 40 of Set 9 | dombarovskiy
# Processing Record 41 of Set 9 | borogontsy
# Processing Record 42 of Set 9 | shache
# Processing Record 43 of Set 9 | luanda
# Processing Record 44 of Set 9 | paamiut
# Processing Record 45 of Set 9 | nioro
# Processing Record 46 of Set 9 | hokitika
# Processing Record 47 of Set 9 | novopavlovka
# Processing Record 48 of Set 9 | khao wong
# Processing Record 49 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 9 | pecanha
# Processing Record 1 of Set 10 | cockburn town
# Processing Record 2 of Set 10 | suriapet
# Processing Record 3 of Set 10 | bima
# Processing Record 4 of Set 10 | boksitogorsk
# Processing Record 5 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 10 | chifeng
# Processing Record 7 of Set 10 | romny
# Processing Record 8 of Set 10 | ciudad bolivar
# Processing Record 9 of Set 10 | maceio
# Processing Record 10 of Set 10 | nuevo progreso
# Processing Record 11 of Set 10 | lima
# Processing Record 12 of Set 10 | kamphaeng phet
# Processing Record 13 of Set 10 | les cayes
# Processing Record 14 of Set 10 | tessalit
# Processing Record 15 of Set 10 | juneau
# Processing Record 16 of Set 10 | fort-shevchenko
# Processing Record 17 of Set 10 | plouzane
# Processing Record 18 of Set 10 | eirunepe
# Processing Record 19 of Set 10 | kalomo
# City not found. Skipping...
# Processing Record 20 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 21 of Set 10 | eidfjord
# Processing Record 22 of Set 10 | saint-georges
# Processing Record 23 of Set 10 | bintulu
# Processing Record 24 of Set 10 | mazulskiy
# City not found. Skipping...
# Processing Record 25 of Set 10 | wagar
# Processing Record 26 of Set 10 | kirkuk
# Processing Record 27 of Set 10 | sun valley
# Processing Record 28 of Set 10 | aksu
# Processing Record 29 of Set 10 | manuk mangkaw
# Processing Record 30 of Set 10 | srednekolymsk
# Processing Record 31 of Set 10 | umm lajj
# Processing Record 32 of Set 10 | ulkan
# Processing Record 33 of Set 10 | lashio
# Processing Record 34 of Set 10 | abong mbang
# Processing Record 35 of Set 10 | guatire
# Processing Record 36 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 37 of Set 10 | bengkulu
# Processing Record 38 of Set 10 | azul
# Processing Record 39 of Set 10 | canutama
# Processing Record 40 of Set 10 | yatou
# Processing Record 41 of Set 10 | whitehorse
# Processing Record 42 of Set 10 | praia
# Processing Record 43 of Set 10 | yar-sale
# Processing Record 44 of Set 10 | doha
# Processing Record 45 of Set 10 | sovetskiy
# Processing Record 46 of Set 10 | nishihara
# Processing Record 47 of Set 10 | ramsar
# Processing Record 48 of Set 10 | galesong
# Processing Record 49 of Set 10 | urucara
# Processing Record 50 of Set 10 | tarakan
# Processing Record 1 of Set 11 | ust-ilimsk
# Processing Record 2 of Set 11 | torremolinos
# Processing Record 3 of Set 11 | mazagao
# Processing Record 4 of Set 11 | eydhafushi
# Processing Record 5 of Set 11 | yialos
# City not found. Skipping...
# Processing Record 6 of Set 11 | batagay-alyta
# Processing Record 7 of Set 11 | kaeo
# Processing Record 8 of Set 11 | syumsi
# Processing Record 9 of Set 11 | ukiah
# Processing Record 10 of Set 11 | marawi
# Processing Record 11 of Set 11 | shieli
# Processing Record 12 of Set 11 | itarema
# Processing Record 13 of Set 11 | havre-saint-pierre
# Processing Record 14 of Set 11 | minab
# Processing Record 15 of Set 11 | omboue
# Processing Record 16 of Set 11 | camacupa
# Processing Record 17 of Set 11 | ferrol
# Processing Record 18 of Set 11 | ambovombe
# Processing Record 19 of Set 11 | seydi
# Processing Record 20 of Set 11 | sorong
# Processing Record 21 of Set 11 | adrar
# Processing Record 22 of Set 11 | ancud
# Processing Record 23 of Set 11 | dickinson
# Processing Record 24 of Set 11 | porto nacional
# Processing Record 25 of Set 11 | gornopravdinsk
# Processing Record 26 of Set 11 | mokolo
# Processing Record 27 of Set 11 | hambantota
# Processing Record 28 of Set 11 | ordu
# Processing Record 29 of Set 11 | buraydah
# Processing Record 30 of Set 11 | hanzhong
# Processing Record 31 of Set 11 | clyde river
# Processing Record 32 of Set 11 | cam ranh
# Processing Record 33 of Set 11 | novobiryusinskiy
# Processing Record 34 of Set 11 | shubarshi
# Processing Record 35 of Set 11 | vieques
# Processing Record 36 of Set 11 | zachary
# Processing Record 37 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 11 | barda
# Processing Record 39 of Set 11 | seguin
# Processing Record 40 of Set 11 | billings
# Processing Record 41 of Set 11 | maghama
# City not found. Skipping...
# Processing Record 42 of Set 11 | poltavka
# Processing Record 43 of Set 11 | kantunilkin
# Processing Record 44 of Set 11 | zhumadian
# Processing Record 45 of Set 11 | la baneza
# Processing Record 46 of Set 11 | nadym
# Processing Record 47 of Set 11 | durango
# Processing Record 48 of Set 11 | susanville
# Processing Record 49 of Set 11 | tikrit
# Processing Record 50 of Set 11 | laureles
# Processing Record 1 of Set 12 | caibarien
# Processing Record 2 of Set 12 | brawley
# Processing Record 3 of Set 12 | port-cartier
# Processing Record 4 of Set 12 | kelvington
# Processing Record 5 of Set 12 | bilibino
# Processing Record 6 of Set 12 | fortuna
# Processing Record 7 of Set 12 | strezhevoy
# Processing Record 8 of Set 12 | evensk
# Processing Record 9 of Set 12 | luena
# Processing Record 10 of Set 12 | qaqortoq
# Processing Record 11 of Set 12 | tateyama
# Processing Record 12 of Set 12 | bambari
# Processing Record 13 of Set 12 | el alto
# Processing Record 14 of Set 12 | itaqui
# Processing Record 15 of Set 12 | khonsar
# City not found. Skipping...
# Processing Record 16 of Set 12 | mount pleasant
# Processing Record 17 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 18 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 12 | balkanabat
# Processing Record 21 of Set 12 | varhaug
# Processing Record 22 of Set 12 | ocean city
# Processing Record 23 of Set 12 | slave lake
# Processing Record 24 of Set 12 | coquimbo
# Processing Record 25 of Set 12 | imbituba
# Processing Record 26 of Set 12 | mapimi
# Processing Record 27 of Set 12 | traverse city
# Processing Record 28 of Set 12 | harigue
# City not found. Skipping...
# Processing Record 29 of Set 12 | maracaju
# Processing Record 30 of Set 12 | ishinomaki
# Processing Record 31 of Set 12 | north platte
# Processing Record 32 of Set 12 | sistranda
# Processing Record 33 of Set 12 | hinesville
# Processing Record 34 of Set 12 | shizuishan
# Processing Record 35 of Set 12 | haines junction
# Processing Record 36 of Set 12 | shostka
# Processing Record 37 of Set 12 | novaya zaimka
# Processing Record 38 of Set 12 | naryan-mar
# Processing Record 39 of Set 12 | zabaykalsk
# Processing Record 40 of Set 12 | aleksandrov gay
# Processing Record 41 of Set 12 | mopti
# Processing Record 42 of Set 12 | alta floresta
# Processing Record 43 of Set 12 | yeppoon
# Processing Record 44 of Set 12 | gouyave
# Processing Record 45 of Set 12 | kodinsk
# Processing Record 46 of Set 12 | westport
# Processing Record 47 of Set 12 | antofagasta
# Processing Record 48 of Set 12 | manokwari
# Processing Record 49 of Set 12 | den helder
# Processing Record 50 of Set 12 | tsabong
# Processing Record 1 of Set 13 | montes claros
# Processing Record 2 of Set 13 | samana
# Processing Record 3 of Set 13 | sandpoint
# Processing Record 4 of Set 13 | mersin
# Processing Record 5 of Set 13 | xichang
# Processing Record 6 of Set 13 | kita
# Processing Record 7 of Set 13 | vanderhoof
# Processing Record 8 of Set 13 | mabaruma
# Processing Record 9 of Set 13 | puerto del rosario
# Processing Record 10 of Set 13 | podgornoye
# Processing Record 11 of Set 13 | boyolangu
# Processing Record 12 of Set 13 | colares
# Processing Record 13 of Set 13 | half moon bay
# Processing Record 14 of Set 13 | santa cruz
# Processing Record 15 of Set 13 | isabela
# Processing Record 16 of Set 13 | tulum
# Processing Record 17 of Set 13 | san fernando
# Processing Record 18 of Set 13 | ballina
# Processing Record 19 of Set 13 | mackenzie
# Processing Record 20 of Set 13 | ryotsu
# Processing Record 21 of Set 13 | sawakin
# Processing Record 22 of Set 13 | pedasi
# Processing Record 23 of Set 13 | berea
# Processing Record 24 of Set 13 | bonavista
# Processing Record 25 of Set 13 | am timan
# Processing Record 26 of Set 13 | seoul
# Processing Record 27 of Set 13 | lunglei
# Processing Record 28 of Set 13 | yumen
# Processing Record 29 of Set 13 | izmalkovo
# Processing Record 30 of Set 13 | jacqueville
# Processing Record 31 of Set 13 | ajaccio
# Processing Record 32 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 13 | channel-port aux basques
# Processing Record 34 of Set 13 | khor
# Processing Record 35 of Set 13 | nkhata bay
# Processing Record 36 of Set 13 | fandriana
# Processing Record 37 of Set 13 | champerico
# Processing Record 38 of Set 13 | muros
# Processing Record 39 of Set 13 | emerald
# Processing Record 40 of Set 13 | pingliang
# Processing Record 41 of Set 13 | fengzhen
# Processing Record 42 of Set 13 | mounana
# Processing Record 43 of Set 13 | lamu
# Processing Record 44 of Set 13 | hanting
# Processing Record 45 of Set 13 | lasa
# Processing Record 46 of Set 13 | camacha
# Processing Record 47 of Set 13 | asau
# Processing Record 48 of Set 13 | dubbo
# Processing Record 49 of Set 13 | acapulco
# Processing Record 50 of Set 13 | ihosy
# Processing Record 1 of Set 14 | pierrelatte
# Processing Record 2 of Set 14 | saint-ambroise
# Processing Record 3 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 4 of Set 14 | vierzon
# Processing Record 5 of Set 14 | meghri
# Processing Record 6 of Set 14 | atyrau
# Processing Record 7 of Set 14 | salinopolis
# Processing Record 8 of Set 14 | dukat
# Processing Record 9 of Set 14 | pemba
# Processing Record 10 of Set 14 | broome
# Processing Record 11 of Set 14 | sonoita
# Processing Record 12 of Set 14 | muisne
# Processing Record 13 of Set 14 | orel-izumrud
# Processing Record 14 of Set 14 | saint-augustin
# Processing Record 15 of Set 14 | mitsamiouli
# Processing Record 16 of Set 14 | beyneu
# Processing Record 17 of Set 14 | san quintin
# Processing Record 18 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 19 of Set 14 | san ramon
# Processing Record 20 of Set 14 | moscow
# Processing Record 21 of Set 14 | kompaniyivka
# Processing Record 22 of Set 14 | yuci
# Processing Record 23 of Set 14 | launceston
# Processing Record 24 of Set 14 | murgab
# Processing Record 25 of Set 14 | krasnoselkup
# Processing Record 26 of Set 14 | vire
# Processing Record 27 of Set 14 | boddam
# Processing Record 28 of Set 14 | scarborough
# Processing Record 29 of Set 14 | portel
# Processing Record 30 of Set 14 | oxford
# Processing Record 31 of Set 14 | dudinka
# Processing Record 32 of Set 14 | nanortalik
# Processing Record 33 of Set 14 | balkhash
# Processing Record 34 of Set 14 | nuuk
# Processing Record 35 of Set 14 | yulara
# Processing Record 36 of Set 14 | priargunsk
# Processing Record 37 of Set 14 | mahibadhoo
# Processing Record 38 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 39 of Set 14 | komsomolskiy
# Processing Record 40 of Set 14 | virginia beach
# Processing Record 41 of Set 14 | tazmalt
# Processing Record 42 of Set 14 | inirida
# Processing Record 43 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 14 | fare
# Processing Record 45 of Set 14 | pisco
# Processing Record 46 of Set 14 | utena
# Processing Record 47 of Set 14 | formosa
# Processing Record 48 of Set 14 | los llanos de aridane
# Processing Record 49 of Set 14 | hobyo
# Processing Record 50 of Set 14 | kichera
# Processing Record 1 of Set 15 | bongandanga
# Processing Record 2 of Set 15 | olinda
# Processing Record 3 of Set 15 | kidal
# Processing Record 4 of Set 15 | atasu
# Processing Record 5 of Set 15 | phrai bung
# City not found. Skipping...
# Processing Record 6 of Set 15 | tarut
# Processing Record 7 of Set 15 | zagora
# Processing Record 8 of Set 15 | yaya
# Processing Record 9 of Set 15 | amuntai
# Processing Record 10 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 11 of Set 15 | faya
# Processing Record 12 of Set 15 | vryheid
# Processing Record 13 of Set 15 | mount darwin
# Processing Record 14 of Set 15 | bethlehem
# Processing Record 15 of Set 15 | kralendijk
# Processing Record 16 of Set 15 | yarensk
# Processing Record 17 of Set 15 | medford
# Processing Record 18 of Set 15 | kenitra
# Processing Record 19 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 15 | stara synyava
# Processing Record 21 of Set 15 | kysyl-syr
# Processing Record 22 of Set 15 | juifang
# City not found. Skipping...
# Processing Record 23 of Set 15 | hagenow
# Processing Record 24 of Set 15 | kalevala
# Processing Record 25 of Set 15 | zholymbet
# Processing Record 26 of Set 15 | nalut
# Processing Record 27 of Set 15 | tete
# Processing Record 28 of Set 15 | riyadh
# Processing Record 29 of Set 15 | bonthe
# Processing Record 30 of Set 15 | harper
# Processing Record 31 of Set 15 | raymond
# Processing Record 32 of Set 15 | dicabisagan
# Processing Record 33 of Set 15 | kerrville
# Processing Record 34 of Set 15 | acarau
# Processing Record 35 of Set 15 | port hardy
# Processing Record 36 of Set 15 | sincelejo
# Processing Record 37 of Set 15 | port augusta
# Processing Record 38 of Set 15 | guadalupe y calvo
# Processing Record 39 of Set 15 | akyab
# Processing Record 40 of Set 15 | siparia
# Processing Record 41 of Set 15 | shenjiamen
# Processing Record 42 of Set 15 | ladario
# Processing Record 43 of Set 15 | paracuru
# Processing Record 44 of Set 15 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 45 of Set 15 | sawtell
# Processing Record 46 of Set 15 | imeni poliny osipenko
# Processing Record 47 of Set 15 | nizwa
# Processing Record 48 of Set 15 | cuxhaven
# Processing Record 49 of Set 15 | mezen
# Processing Record 50 of Set 15 | aljezur
# Processing Record 1 of Set 16 | bourail
# Processing Record 2 of Set 16 | evanston
# Processing Record 3 of Set 16 | vuktyl
# Processing Record 4 of Set 16 | okandja
# City not found. Skipping...
# Processing Record 5 of Set 16 | ngama
# Processing Record 6 of Set 16 | mount gambier
# Processing Record 7 of Set 16 | sivas
# Processing Record 8 of Set 16 | kudymkar
# Processing Record 9 of Set 16 | luwuk
# Processing Record 10 of Set 16 | black river
# Processing Record 11 of Set 16 | livingston
# Processing Record 12 of Set 16 | ouallam
# Processing Record 13 of Set 16 | xining
# Processing Record 14 of Set 16 | kirakira
# Processing Record 15 of Set 16 | kinsale
# Processing Record 16 of Set 16 | fort frances
# Processing Record 17 of Set 16 | flin flon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Alice Springs      AU -23.7000  133.8833     56.75        67          40
# 1          Kodiak      US  57.7900 -152.4072     40.51        81         100
# 2  Grande Prairie      CA  55.1667 -118.8027     41.18        93         100
# 3         Warmbad      NA -28.4500   18.7333     70.20        14           0
# 4   Pozo Colorado      PY -23.4923  -58.7972     88.39        45           0
# 5        Mercedes      AR -34.6515  -59.4307     66.85        41           0
# 6           Alofi      NU -19.0595 -169.9187     80.92        79          99
# 7       Kununurra      AU -15.7667  128.7333     85.98        37           9
# 8        Hukuntsi      BW -24.0000   21.7500     69.60        21           0
# 9     Provideniya      RU  64.3833 -173.3000     23.86        76          88
#
#    Wind Speed Current Description
# 0        4.61    scattered clouds
# 1       17.27          light rain
# 2        5.75     overcast clouds
# 3       10.83           clear sky
# 4        4.90           clear sky
# 5        7.65           clear sky
# 6       12.59     overcast clouds
# 7       11.50           clear sky
# 8        8.66           clear sky
# 9       11.70     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
